# %%
import numpy as np
import pandas as pd
import seaborn as sns

np.__version__, pd.__version__, sns.__version__
# Out:
# ('1.19.5', '1.2.4', '0.11.1')

# %%
# %matplotlib inline
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips, x='total_bill', y='tip')

# %%
sns.relplot(data=tips, x='total_bill', y='tip', hue='sex')

# %%
sns.relplot(data=tips, x='total_bill', y='tip', hue='sex', size='size')

# %%
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde')

# %%
sns.displot(data=tips, x='tip', hue='sex', kind='kde')

# %%
sns.displot(data=tips, x='tip', hue='sex', kind='ecdf')

# %%
sns.displot(data=tips, x='tip', hue='size', kind='ecdf')

# %%
sns.histplot(data=tips, x='tip', hue='size', binwidth=0.50)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')
tips.loc[:,'percent']=100*tips.loc[:,'tip']/tips.loc[:,'total_bill']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size    percent
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441
#
# [244 rows x 8 columns]

# %%
# tips.loc['percent'].drop('percent',axis=0)
# Out:
# total_bill    NaN
# tip           NaN
# sex           NaN
# smoker        NaN
# day           NaN
# time          NaN
# size          NaN
# Name: percent, dtype: object

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size    percent
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441
#
# [244 rows x 8 columns]

# %%
sns.histplot(data=tips, x='percent', hue='day', binwidth=2)
# Out:
# <AxesSubplot:xlabel='percent', ylabel='Count'>

# %%
sns.displot(data=tips, x='percent',
            hue='sex', 
            kind='ecdf')

# %%
sorted_tips = tips.sort_values(by='percent', axis=0)
sorted_tips
# Out:
#      total_bill   tip     sex smoker  day    time  size    percent
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2   3.563814
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3   5.643341
# 57        26.41  1.50  Female     No  Sat  Dinner     2   5.679667
# 0         16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5   6.565988
# ..          ...   ...     ...    ...  ...     ...   ...        ...
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4  28.053517
# 232       11.61  3.39    Male     No  Sat  Dinner     2  29.198966
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  32.573290
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  41.666667
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  71.034483
#
# [244 rows x 8 columns]

# %%
sns.histplot(data=sorted_tips, x='percent', hue='day', binwidth=2)
# Out:
# <AxesSubplot:xlabel='percent', ylabel='Count'>

# %% [markdown]
# ## Missing data

# %%
s = pd.Series([1, 2])
s
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s[0] = None
s
# Out:
# 0    NaN
# 1    2.0
# dtype: float64

# %%
s = pd.Series([1, 2], dtype=object)
s
# Out:
# 0    1
# 1    2
# dtype: object

# %%
s[0] = None
s[1] = np.nan
s
# Out:
# 0    None
# 1     NaN
# dtype: object

# %%
areas = ['area A', 'area B', 'area C']
pop_all = pd.Series([None, 130, 101], index=areas)
pop_male = pd.Series([120, None, 50], index=areas)
pop_area = pd.DataFrame({'all':pop_all, 'male':pop_male})
pop_area
# Out:
#           all   male
# area A    NaN  120.0
# area B  130.0    NaN
# area C  101.0   50.0

# %%
pop_area.isna()
# Out:
#           all   male
# area A   True  False
# area B  False   True
# area C  False  False

# %%
pop_area.notna()
# Out:
#           all   male
# area A  False   True
# area B   True  False
# area C   True   True

# %%
pop_area_pdna = pd.DataFrame({'all':pop_all, 'male':pop_male},dtype='Float64')
pop_area_pdna
# Out:
#           all   male
# area A   <NA>  120.0
# area B  130.0   <NA>
# area C  101.0   50.0

# %%
pop_area.notna()
# Out:
#           all   male
# area A  False   True
# area B   True  False
# area C   True   True

# %%
p = pd.DataFrame([[1, 2, np.nan], [3, np.nan, np.nan], [7, 5, np.nan], [9, 9, 9]], dtype='UInt8')
p
# Out:
#    0     1     2
# 0  1     2  <NA>
# 1  3  <NA>  <NA>
# 2  7     5  <NA>
# 3  9     9     9

# %%
p.dropna()
# Out:
#    0  1  2
# 3  9  9  9

# %%
p.dropna(axis=1)
# Out:
#    0
# 0  1
# 1  3
# 2  7
# 3  9

# %%
p.dropna(how='all') # remove rows with only missing values
# Out:
#    0     1     2
# 0  1     2  <NA>
# 1  3  <NA>  <NA>
# 2  7     5  <NA>
# 3  9     9     9

# %%
p = pd.DataFrame([[1, 2, np.nan], [3, np.nan, np.nan], [7, 5, np.nan], [9, 9, 9], [pd.NA, pd.NA, pd.NA]], dtype='UInt8')
p
# Out:
#       0     1     2
# 0     1     2  <NA>
# 1     3  <NA>  <NA>
# 2     7     5  <NA>
# 3     9     9     9
# 4  <NA>  <NA>  <NA>

# %%
p.dropna(how='all')
# Out:
#    0     1     2
# 0  1     2  <NA>
# 1  3  <NA>  <NA>
# 2  7     5  <NA>
# 3  9     9     9

# %%
p.dropna(thresh=2) # remove rows with at least two missing values
# Out:
#    0  1     2
# 0  1  2  <NA>
# 2  7  5  <NA>
# 3  9  9     9

# %%
sns.relplot(data=tips, x='total_bill', y='percent', hue='time', size='size', sizes=(1, 200), alpha=0.5)

# %%
p.fillna(128)
# Out:
#      0    1    2
# 0    1    2  128
# 1    3  128  128
# 2    7    5  128
# 3    9    9    9
# 4  128  128  128

# %%
p.fillna(method='bfill')
# Out:
#       0     1     2
# 0     1     2     9
# 1     3     5     9
# 2     7     5     9
# 3     9     9     9
# 4  <NA>  <NA>  <NA>

# %%
p.fillna(method='bfill', axis=1)
# Out:
#       0     1     2
# 0     1     2  <NA>
# 1     3  <NA>  <NA>
# 2     7     5  <NA>
# 3     9     9     9
# 4  <NA>  <NA>  <NA>

# %%
p.fillna(method='ffill')
# Out:
#    0  1     2
# 0  1  2  <NA>
# 1  3  2  <NA>
# 2  7  5  <NA>
# 3  9  9     9
# 4  9  9     9

# %%
p.fillna(method='ffill', axis=1)
# Out:
#       0     1     2
# 0     1     2     2
# 1     3     3     3
# 2     7     5     5
# 3     9     9     9
# 4  <NA>  <NA>  <NA>

# %%
p = pd.DataFrame([[1, 2, np.nan], [5, np.nan, np.nan],
[np.nan, np.nan, np.nan]],
index=list('abc'), columns=list('xyz'))
p
# Out:
#      x    y   z
# a  1.0  2.0 NaN
# b  5.0  NaN NaN
# c  NaN  NaN NaN

# %%
p.mean()
# Out:
# x    3.0
# y    2.0
# z    NaN
# dtype: float64

# %%
# NotImplementedError if we fill on axis=1
p.fillna(p.mean())
# Out:
#      x    y   z
# a  1.0  2.0 NaN
# b  5.0  2.0 NaN
# c  3.0  2.0 NaN

# %%
p.apply(lambda s: s.fillna(s.mean()), axis=1)
# Out:
#      x    y    z
# a  1.0  2.0  1.5
# b  5.0  5.0  5.0
# c  NaN  NaN  NaN

# %%
p.apply(lambda s: s.fillna(s.mean()))
# Out:
#      x    y   z
# a  1.0  2.0 NaN
# b  5.0  2.0 NaN
# c  3.0  2.0 NaN

# %%
df = pd.DataFrame([list('abc'), list('acd'), list('xyz')], columns=list('ABC'))
df
# Out:
#    A  B  C
# 0  a  b  c
# 1  a  c  d
# 2  x  y  z

# %%
df.replace('a', pd.NA)
# Out:
#       A  B  C
# 0  <NA>  b  c
# 1  <NA>  c  d
# 2     x  y  z

# %%
df.replace(['a', 'x'], pd.NA)
# Out:
#       A  B  C
# 0  <NA>  b  c
# 1  <NA>  c  d
# 2  <NA>  y  z

# %%
df.replace(['a', 'x'], [-1, -2])
# Out:
#    A  B  C
# 0 -1  b  c
# 1 -1  c  d
# 2 -2  y  z

# %%
s = pd.Series(['alice', 'bob', 'Bill'])
s
# Out:
# 0    alice
# 1      bob
# 2     Bill
# dtype: object

# %%
s.where(s.str.islower(), pd.NA)
# Out:
# 0    alice
# 1      bob
# 2     <NA>
# dtype: object

# %%
s = pd.Series(np.random.randint(-10, 10, 5),dtype='Int32')

# %%
s.where(s>4, pd.NA)
# Out:
# 0    <NA>
# 1       8
# 2    <NA>
# 3    <NA>
# 4    <NA>
# dtype: Int32

# %%
df = pd.DataFrame([[10, 120], [12, 130], [13, 140]], index=['alice', 'bob', 'eve'], columns=['age','height'])
df
# Out:
#        age  height
# alice   10     120
# bob     12     130
# eve     13     140

# %%
s = pd.Series([125, 135, 145], name='height', index=['alice', 'bob', 'eve'])
df.update(s)
df
# Out:
#        age  height
# alice   10     125
# bob     12     135
# eve     13     145

# %%
df1 = pd.DataFrame({'A': [1., np.nan, 3.], 'B': [np.nan, np.nan, 3.]})
df2 = pd.DataFrame({'A': [1., 8, 3.], 'B':[10, np.nan, 3.]})

# %%
df1
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  NaN
# 2  3.0  3.0

# %%
df2
# Out:
#      A     B
# 0  1.0  10.0
# 1  8.0   NaN
# 2  3.0   3.0

# %%
df1.combine_first(df2)
# Out:
#      A     B
# 0  1.0  10.0
# 1  8.0   NaN
# 2  3.0   3.0

# %%
df = pd.DataFrame([1, 2, np.nan])

# %%
(df == df).all()
# Out:
# 0    False
# dtype: bool

# %%
df.equals(df)
# Out:
# True

# %%
df = pd.DataFrame([[10, 120], [12, 130], [13, 140]],index=['alice', 'bob', 'eve'], columns=['age','height'])
df2 = df.copy()
df2.loc['alice', 'age'] = 12
df.compare(df2)
# Out:
#         age
#        self other
# alice  10.0  12.0

# %%
df.compare(df2, keep_shape=True)
# Out:
#         age       height
#        self other   self other
# alice  10.0  12.0    NaN   NaN
# bob     NaN   NaN    NaN   NaN
# eve     NaN   NaN    NaN   NaN

# %%
s = pd.Series([1, 1, 3, 3, 3, 5, 5, 7, 7, 7, 7])
s.value_counts()
# Out:
# 7    4
# 3    3
# 1    2
# 5    2
# dtype: int64

# %%
s.mode()
# Out:
# 0    7
# dtype: int64

# %%
s.unique()
# Out:
# array([1, 3, 5, 7])

# %%
s1 = pd.Series(np.random.randn(10))
s1
# Out:
# 0   -2.825629
# 1    0.401196
# 2   -0.523833
# 3   -0.849454
# 4    0.889691
# 5    0.105404
# 6    0.807912
# 7    1.137299
# 8   -0.902753
# 9    0.277270
# dtype: float64

# %%
s1.idxmin(), s1.idxmax()
# Out:
# (0, 7)

# %%
import matplotlib.pyplot as plt
plt.plot(s.value_counts())

# %%
t = tips.loc[:,'tip']
f"{t.mean()=:.2f}, {t.mad()=:.2f}, {t.min()=:.2f},{t.max()=:.2f}"
# Out:
# 't.mean()=3.00, t.mad()=1.03, t.min()=1.00,t.max()=10.00'

# %%
tips.describe()
# Out:
#        total_bill         tip        size     percent
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672   16.080258
# std      8.902412    1.383638    0.951100    6.107220
# min      3.070000    1.000000    1.000000    3.563814
# 25%     13.347500    2.000000    2.000000   12.912736
# 50%     17.795000    2.900000    2.000000   15.476977
# 75%     24.127500    3.562500    3.000000   19.147549
# max     50.810000   10.000000    6.000000   71.034483

# %%
tips[['sex', 'day', 'smoker']].describe()
# Out:
#          sex  day smoker
# count    244  244    244
# unique     2    4      2
# top     Male  Sat     No
# freq     157   87    151

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size  \
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000
#
#            percent
# count   244.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean     16.080258
# ...

# %%
import seaborn as sns
sns.relplot(data=tips, x='total_bill', y='tip', hue='sex', size='size',style='time')
plt.savefig('tips.png')
plt.show()

# %%
names = ['alice ', ' bOB', 'Marc', 'bill', 3, ' JULIE', np.nan]
age = pd.Series(names)
age = age.str.lower().str.strip() # [...].str.[...]
print(age)
# Out:
# 0    alice
# 1      bob
# 2     marc
# 3     bill
# 4      NaN
# 5    julie
# 6      NaN
# dtype: object

# %%
age.str[3]
# Out:
# 0      c
# 1    NaN
# 2      c
# 3      l
# 4    NaN
# 5      i
# 6    NaN
# dtype: object

# %%
age.str[:2]
# Out:
# 0     al
# 1     bo
# 2     ma
# 3     bi
# 4    NaN
# 5     ju
# 6    NaN
# dtype: object

# %%
array = np.random.randint(1, 10, size=(3,2))
df = pd.DataFrame(array, columns=[' col A ', 'Col b'], index=range(3))
print(df)
# Out:
#     col A   Col b
# 0        7      4
# 1        9      5
# 2        3      1

# %%
df.columns = (df.columns
.str.strip()
.str.lower()
.str.replace(' ', '_'))
print(df)
# Out:
#    col_a  col_b
# 0      7      4
# 1      9      5
# 2      3      1

# %%
df = pd.DataFrame({'who': ('alice', 'bob'), 'age': [12, 15]})

# %%
df = pd.DataFrame({'who': ('alice', 'bob'), 'age': [12, 15]})
df.who = df.who.str.upper()
df
# Out:
#      who  age
# 0  ALICE   12
# 1    BOB   15

# %%
s = pd.Series(['good', 'average', 'best', 'poor','good'])
s
# Out:
# 0       good
# 1    average
# 2       best
# 3       poor
# 4       good
# dtype: object

# %%
s.astype('category')
# Out:
# 0       good
# 1    average
# 2       best
# 3       poor
# 4       good
# dtype: category
# Categories (4, object): ['average', 'best', 'good', 'poor']

# %%
s = pd.Series(['good', 'average', 'best', 'poor','good'], dtype='category')
s
# Out:
# 0       good
# 1    average
# 2       best
# 3       poor
# 4       good
# dtype: category
# Categories (4, object): ['average', 'best', 'good', 'poor']

# %%
s = pd.Series(['good', 'average', 'best', 'poor',
'good'], dtype=pd.CategoricalDtype(categories=['best',
'good', 'average', 'poor'], ordered=True))
s
# Out:
# 0       good
# 1    average
# 2       best
# 3       poor
# 4       good
# dtype: category
# Categories (4, object): ['best' < 'good' < 'average' < 'poor']

# %%
s.sort_values()
# Out:
# 2       best
# 0       good
# 4       good
# 1    average
# 3       poor
# dtype: category
# Categories (4, object): ['best' < 'good' < 'average' < 'poor']

# %%
pd.Series(['good', 'average', 'best', 'poor',
'good'], dtype=pd.CategoricalDtype(
categories=['best', 'average', 'poor'],
ordered=True))
# Out:
# 0        NaN
# 1    average
# 2       best
# 3       poor
# 4        NaN
# dtype: category
# Categories (3, object): ['best' < 'average' < 'poor']

# %%
s2 = pd.Series([10, 20, 30],
index=pd.Index(['alice', 'bob', 'bill'],
dtype='category'))
s2
# Out:
# alice    10
# bob      20
# bill     30
# dtype: int64

# %%
s2.loc['alice']
# Out:
# 10

# %%
s.cat.rename_categories({'best':'b', 'good':'g',
'average':'a','poor':'p'})
# Out:
# 0    g
# 1    a
# 2    b
# 3    p
# 4    g
# dtype: category
# Categories (4, object): ['b' < 'g' < 'a' < 'p']

# %%
s.cat.add_categories('worse')
# Out:
# 0       good
# 1    average
# 2       best
# 3       poor
# 4       good
# dtype: category
# Categories (5, object): ['best' < 'good' < 'average' < 'poor' < 'worse']

# %%
s.cat.remove_categories('good')
# Out:
# 0        NaN
# 1    average
# 2       best
# 3       poor
# 4        NaN
# dtype: category
# Categories (3, object): ['best' < 'average' < 'poor']

# %%
s
# Out:
# 0       good
# 1    average
# 2       best
# 3       poor
# 4       good
# dtype: category
# Categories (4, object): ['best' < 'good' < 'average' < 'poor']

# %%
s.cat.ordered
# Out:
# True

# %%
s.cat.reorder_categories(['poor', 'average',
'good', 'best'], inplace=True)

# %%
s
# Out:
# 0       good
# 1    average
# 2       best
# 3       poor
# 4       good
# dtype: category
# Categories (4, object): ['poor' < 'average' < 'good' < 'best']

# %%
s1 = pd.Series([30, 35, 20], index=['alice', 'bob','julie'])
s2 = pd.Series([55, 80, 50], index=['alice', 'bob','julie'])
df = pd.DataFrame({'age': s1, 'poids': s2})
df
# Out:
#        age  poids
# alice   30     55
# bob     35     80
# julie   20     50

# %%
s = df.unstack()
s
# Out:
# age    alice    30
#        bob      35
#        julie    20
# poids  alice    55
#        bob      80
#        julie    50
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# MultiIndex([(  'age', 'alice'),
#             (  'age',   'bob'),
#             (  'age', 'julie'),
#             ('poids', 'alice'),
#             ('poids',   'bob'),
#             ('poids', 'julie')],
#            )

# %%
s.index.to_flat_index()
# Out:
# Index([  ('age', 'alice'),     ('age', 'bob'),   ('age', 'julie'),
#        ('poids', 'alice'),   ('poids', 'bob'), ('poids', 'julie')],
#       dtype='object')

# %%
names = ['alice', 'alice', 'alice', 'bob', 'bob','bob']
age = [2014, 2015, 2016, 2014, 2015, 2016]
s_list = pd.Series([40, 42, 45, 38, 40, 40],index=[names, age])
s_list
# Out:
# alice  2014    40
#        2015    42
#        2016    45
# bob    2014    38
#        2015    40
#        2016    40
# dtype: int64

# %%
s_tuple = pd.Series({
        ('alice', 2014): 40,
        ('alice', 2015): 42,
        ('alice', 2016): 45,
        ('bob', 2014): 38,
        ('bob', 2015): 40,
        ('bob', 2016): 40})
s_tuple
# Out:
# alice  2014    40
#        2015    42
#        2016    45
# bob    2014    38
#        2015    40
#        2016    40
# dtype: int64

# %%
s_bad_tuples = pd.Series({('alice', 2014): 40,
                          ('alice', 2015): 42,
                          ('alice', 2016): 45,
                          ('bob', 2014): 38,
                          ('bob', 2015): 40,
                          ('bob'): 40})
s_bad_tuples
# Out:
# (alice, 2014)    40
# (alice, 2015)    42
# (alice, 2016)    45
# (bob, 2014)      38
# (bob, 2015)      40
# bob              40
# dtype: int64

# %%
def f(a,b,c):
    return a**2 + 3*b - c

# %%
f(1,2,3)
# Out:
# 4

# %%
f = lambda a,b,c: a**2+3*b-c

# %%
f(1,2,3)
# Out:
# 4

# %%
s_list.index
# Out:
# MultiIndex([('alice', 2014),
#             ('alice', 2015),
#             ('alice', 2016),
#             (  'bob', 2014),
#             (  'bob', 2015),
#             (  'bob', 2016)],
#            )

# %%
s_tuple.index
# Out:
# MultiIndex([('alice', 2014),
#             ('alice', 2015),
#             ('alice', 2016),
#             (  'bob', 2014),
#             (  'bob', 2015),
#             (  'bob', 2016)],
#            )

# %%
s_bad_tuples.index
# Out:
# Index([('alice', 2014), ('alice', 2015), ('alice', 2016),   ('bob', 2014),
#          ('bob', 2015),           'bob'],
#       dtype='object')

# %%
name = ['alice', 'bob']
year = [2014, 2015, 2016]
i = pd.MultiIndex.from_product([name, year], names = ['name', 'year'])
s = pd.Series([40, 42, 45, 38, 40, 40], index = i)
s
# Out:
# name   year
# alice  2014    40
#        2015    42
#        2016    45
# bob    2014    38
#        2015    40
#        2016    40
# dtype: int64

# %%
s.unstack()
# Out:
# year   2014  2015  2016
# name
# alice    40    42    45
# bob      38    40    40

# %%
s_list.index.names
# Out:
# FrozenList([None, None])

# %%
s_list.index.names = ['names', 'years']

# %%
s_list.index
# Out:
# MultiIndex([('alice', 2014),
#             ('alice', 2015),
#             ('alice', 2016),
#             (  'bob', 2014),
#             (  'bob', 2015),
#             (  'bob', 2016)],
#            names=['names', 'years'])

# %%
s_list.index.names|
# Out:
# FrozenList(['names', 'years'])

# %%
s_list
# Out:
# names  years
# alice  2014     40
#        2015     42
#        2016     45
# bob    2014     38
#        2015     40
#        2016     40
# dtype: int64

# %%
# index for years and visits
index = pd.MultiIndex.from_product([[2013, 2014],[1, 2, 3]],names=['year','visit'])
# columns for clients and tyre pressure
columns = pd.MultiIndex.from_product([['Bob', 'Sue'],['Front', 'Rear']],names=['client','tyre pressure'])
# mock some data
data = 2 + np.random.rand(6, 4)
# create the DataFrame
mecanics_data = pd.DataFrame(data, index=index, columns=columns)
mecanics_data
# Out:
# client              Bob                 Sue
# tyre pressure     Front      Rear     Front      Rear
# year visit
# 2013 1         2.006122  2.560013  2.964798  2.067791
#      2         2.676155  2.964886  2.096023  2.716016
#      3         2.038835  2.559158  2.813206  2.925914
# 2014 1         2.267845  2.637838  2.013646  2.006635
#      2         2.017556  2.213887  2.042824  2.890243
#      3         2.223484  2.905768  2.189624  2.696427

# %%
mecanics_data.plot(ylabel='pressure')
plt.savefig('mecanics.png')
plt.show()

# %%
mecanics_data.plot.bar()
plt.savefig('mecanics.png')
plt.show()

# %%
mecanics_data.loc[2013, 'Bob']
# Out:
# tyre pressure     Front      Rear
# visit
# 1              2.006122  2.560013
# 2              2.676155  2.964886
# 3              2.038835  2.559158

# %%
mecanics_data.loc[(2013, 2), ('Sue', 'Rear')]
# Out:
# 2.7160162788724507

# %%
mecanics_data.loc[slice((2013, 2),(2014, 1)),('Sue', slice(None))]
# Out:
# client              Sue
# tyre pressure     Front      Rear
# year visit
# 2013 2         2.096023  2.716016
#      3         2.813206  2.925914
# 2014 1         2.013646  2.006635

# %%
mecanics_data.loc[(slice(None), slice(1, 2)),('Sue', slice(None))]
# Out:
# client              Sue
# tyre pressure     Front      Rear
# year visit
# 2013 1         2.964798  2.067791
#      2         2.096023  2.716016
# 2014 1         2.013646  2.006635
#      2         2.042824  2.890243

# %%
mecanics_data.loc[(slice(None), slice(1, 2)), :]
# Out:
# client              Bob                 Sue
# tyre pressure     Front      Rear     Front      Rear
# year visit
# 2013 1         2.006122  2.560013  2.964798  2.067791
#      2         2.676155  2.964886  2.096023  2.716016
# 2014 1         2.267845  2.637838  2.013646  2.006635
#      2         2.017556  2.213887  2.042824  2.890243

# %%
idx = pd.IndexSlice
idx

# %%
mecanics_data.loc[idx[:, 1:2], idx['Sue', :]]
# Out:
# client              Sue
# tyre pressure     Front      Rear
# year visit
# 2013 1         2.964798  2.067791
#      2         2.096023  2.716016
# 2014 1         2.013646  2.006635
#      2         2.042824  2.890243

# %%
mecanics_data.loc[idx[:, [1, 3]], idx['Sue', :]]
# Out:
# client              Sue
# tyre pressure     Front      Rear
# year visit
# 2013 1         2.964798  2.067791
#      3         2.813206  2.925914
# 2014 1         2.013646  2.006635
#      3         2.189624  2.696427

# %%
(mecanics_data['Bob']['Rear'] == mecanics_data.loc[:,('Bob', 'Rear')]).all()
# Out:
# True

# %%
# %timeit mecanics_data['Bob']['Rear']# it is slower
# %timeit mecanics_data.loc[:,('Bob', 'Rear')]
# Out:
# 264 µs ± 27.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 121 µs ± 9.08 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
mecanics_data.loc[:,('Bob', 'Rear')] = 1.2

# %% [markdown]
# ### Concatenation

# %%
s1 = pd.Series([30, 35], index=['alice', 'bob'])
s2 = pd.Series([32, 29], index=['bill', 'jo'])
s = pd.concat([s1, s2])
s
# Out:
# alice    30
# bob      35
# bill     32
# jo       29
# dtype: int64

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('zt'))
pd.concat([p1, p2])
# Out:
#    a  b
# x  2  5
# y  7  7
# z  1  5
# t  4  8

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('cd'), index=list('xy'))
pd.concat([p1, p2], axis=1)
# Out:
#    a  b  c  d
# x  7  2  1  6
# y  6  1  2  3

# %%
pd.concat([p1,p1])
# Out:
#    a  b
# x  7  2
# y  6  1
# x  7  2
# y  6  1

# %%
pd.concat([p1,p1], verify_integrity=True) # error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-223-ab17df120303> in <module>
# ----> 1 pd.concat([p1,p1], verify_integrity=True)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     465         self.copy = copy
#     466
# --> 467         self.new_axes = self._get_new_axes()
#     468
#     469     def get_result(self):
#
# ...

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('zt'))
pd.concat([p1, p2], ignore_index=True)
# Out:
#    a  b
# 0  7  2
# 1  2  9
# 2  8  5
# 3  5  8

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
pd.concat([p1, p2], keys=['X', 'Y'])
# Out:
#      a  b
# X x  9  6
#   y  2  1
# Y x  4  6
#   y  9  7

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('bc'), index=list('zt'))
pd.concat([p1, p2])
# Out:
#      a  b    c
# x  7.0  3  NaN
# y  5.0  7  NaN
# z  NaN  3  9.0
# t  NaN  9  3.0

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('bc'), index=list('zt'))
pd.concat([p1, p2], join='inner')
# Out:
#    b
# x  2
# y  4
# z  5
# t  7

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('bc'), index=list('zt'))
pd.concat([p1, p2]).reindex(['a', 'b'], axis=1)
# Out:
#      a  b
# x  8.0  8
# y  1.0  9
# z  NaN  7
# t  NaN  6

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('bc'), index=list('zt'))
pd.concat([p1, p2]).reindex(p2.columns, axis=1)
# Out:
#    b    c
# x  9  NaN
# y  7  NaN
# z  3  6.0
# t  1  6.0

# %%
p1 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('ab'), index=list('xy'))
p2 = pd.DataFrame(np.random.randint(1, 10, size=(2,2)), columns=list('bc'), index=list('zt'))
p1.append(p2)
# Out:
#      a  b    c
# x  3.0  3  NaN
# y  5.0  8  NaN
# z  NaN  6  7.0
# t  NaN  9  6.0

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Lisa', 'Sue'], 'group': ['Accounting', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Sue'], 'hire_date': [2004, 2008, 2014]})
# Out:
# (  employee        group
#  0      Bob   Accounting
#  1     Lisa  Engineering
#  2      Sue           HR,   employee  hire_date
#  0     Lisa       2004
#  1      Bob       2008
#  2      Sue       2014,   employee        group  hire_date
#  0      Bob   Accounting       2008
#  1     Lisa  Engineering       2004
#  2      Sue           HR       2014)

# %%
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Lisa  Engineering
# 2      Sue           HR

# %%
df2
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2      Sue       2014

# %%
pd.merge(df1,df2)
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Lisa  Engineering       2004
# 2      Sue           HR       2014

# %%
# many-to-one
df1 = pd.DataFrame({'patient': ['Bob', 'Lisa', 'Sue'], 'repas': ['SS', 'SS', 'SSR']})
df2 = pd.DataFrame({'repas': ['SS', 'SSR'], 'explication': ['sans sel', 'sans sucre']})
print(df1)
print(df2)
pd.merge(df1,df2)
# Out:
#   patient repas
# 0     Bob    SS
# 1    Lisa    SS
# 2     Sue   SSR
#   repas explication
# 0    SS    sans sel
# 1   SSR  sans sucre
#   patient repas explication
# 0     Bob    SS    sans sel
# 1    Lisa    SS    sans sel
# 2     Sue   SSR  sans sucre

# %%
# many-to-many
df1 = pd.DataFrame({'patient': ['Bob', 'Lisa', 'Sue'], 'repas': ['SS', 'SS', 'SSR']})
df2 = pd.DataFrame({'repas': ['SS', 'SS', 'SSR'], 'explication': ['sans sel', 'légumes', 'sans sucre']})
print(df1)
print(df2)
pd.merge(df1,df2)
# Out:
#   patient repas
# 0     Bob    SS
# 1    Lisa    SS
# 2     Sue   SSR
#   repas explication
# 0    SS    sans sel
# 1    SS     légumes
# 2   SSR  sans sucre
#   patient repas explication
# 0     Bob    SS    sans sel
# 1     Bob    SS     légumes
# 2    Lisa    SS    sans sel
# 3    Lisa    SS     légumes
# 4     Sue   SSR  sans sucre

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Lisa', 'Sue'], 'group': ['Accounting', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Sue'], 'hire_date': [2004, 2008, 2014]})
print(df1)
print(df2)
pd.merge(df1,df2, on='employee')
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Lisa  Engineering
# 2      Sue           HR
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2      Sue       2014
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Lisa  Engineering       2004
# 2      Sue           HR       2014

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Lisa', 'Sue'], 'group': ['Accounting', 'Engineering', 'HR']})
df2 = pd.DataFrame({'name': ['Lisa', 'Bob', 'Sue'], 'hire_date': [2004, 2008, 2014]})
print(df1)
print(df2)
m = pd.merge(df1,df2, left_on='employee', right_on='name')
m
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Lisa  Engineering
# 2      Sue           HR
#    name  hire_date
# 0  Lisa       2004
# 1   Bob       2008
# 2   Sue       2014
#   employee        group  name  hire_date
# 0      Bob   Accounting   Bob       2008
# 1     Lisa  Engineering  Lisa       2004
# 2      Sue           HR   Sue       2014

# %%
m.drop(columns='name')
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Lisa  Engineering       2004
# 2      Sue           HR       2014

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Lisa', 'Sue'], 'group': ['Accounting', 'Engineering', 'HR']})
df2 = pd.DataFrame({'name': ['Lisa', 'Bob', 'Sue'], 'hire_date': [2004, 2008, 2014]})
# we make the column employee the index of the DataFrame
print(df1)
df1 = df1.set_index('employee')
print(df1)
print(df1.index)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Lisa  Engineering
# 2      Sue           HR
#                 group
# employee
# Bob        Accounting
# Lisa      Engineering
# Sue                HR
# Index(['Bob', 'Lisa', 'Sue'], dtype='object', name='employee')

# %%
pd.merge(df1,df2, left_index= True, right_on='name')
# Out:
#          group  name  hire_date
# 1   Accounting   Bob       2008
# 0  Engineering  Lisa       2004
# 2           HR   Sue       2014

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d2f1ef1d5fc8> in <module>
# ----> 1 df1 = pd.DataFrame({'name': ['Bob', 'Lisa', 'Sue'], 'pulse': [70, 63, 81]})
#       2 df2 = pd.DataFrame({'name': ['Eric', 'Bob', 'Marc'], 'weight': [60, 100, 70]})
#       3 print(df1)
#       4 print(df2)
#       5 pd.merge(df1, df2, how='inner') # default behavior
#
# NameError: name 'pd' is not defined
